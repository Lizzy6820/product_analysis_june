# %%
import pandas as pd
import glob
import os
from dateutil.parser import parse as pr
import seaborn as sns
import matplotlib.pyplot as plt

path = r"C:\Users\DELL E6400\Downloads\product_data"
all_files = glob.glob(os.path.join(path, "*.csv"))     

df_from_each_file = (pd.read_csv(f) for f in all_files)
df  = pd.concat(df_from_each_file, ignore_index=True)
df
# Out:
#        Order ID                     Product Quantity Ordered Price Each  \
# 0        176558        USB-C Charging Cable                2      11.95
# 1           NaN                         NaN              NaN        NaN
# 2        176559  Bose SoundSport Headphones                1      99.99
# 3        176560                Google Phone                1        600
# 4        176560            Wired Headphones                1      11.99
# ...         ...                         ...              ...        ...
# 186845   259353      AAA Batteries (4-pack)                3       2.99
# 186846   259354                      iPhone                1        700
# 186847   259355                      iPhone                1        700
# 186848   259356      34in Ultrawide Monitor                1     379.99
# 186849   259357        USB-C Charging Cable                1      11.95
#
#             Order Date                         Purchase Address
# ...

# %%
df.shape
# Out:
# (186850, 6)

# %%
df.describe()
# Out:
#         Order ID               Product Quantity Ordered Price Each  \
# count     186305                186305           186305     186305
# unique    178438                    20               10         24
# top     Order ID  USB-C Charging Cable                1      11.95
# freq         355                 21903           168552      21903
#
#         Order Date  Purchase Address
# count       186305            186305
# unique      142396            140788
# top     Order Date  Purchase Address
# freq           355               355

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB

# %%
#check for missing values
df.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %%
#drop rows with misssing values
df = df.dropna()
df.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
#create column for amount per product
df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], errors = 'coerce')
df['Price Each'] = pd.to_numeric(df['Price Each'], errors = 'coerce')
df['Amount_Sold'] = df['Price Each'] * df['Quantity Ordered']

#Breakdown the addresses into city, state and postalcode
#df['City'] = df['Purchase Address'].apply(lambda x: x.split(' ')[0].split(',')[1])
df['State'] = df['Purchase Address'].apply(lambda x: x.split()[-2])
df['Postal Code'] = df['Purchase Address'].apply(lambda x: x.split()[-1])
df.head()
# Out:
# C:\Users\DELL E6400\AppData\Local\Temp\ipykernel_14752\4117476002.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Quantity Ordered'] = pd.to_numeric(df['Quantity Ordered'], errors = 'coerce')
# C:\Users\DELL E6400\AppData\Local\Temp\ipykernel_14752\4117476002.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price Each'] = pd.to_numeric(df['Price Each'], errors = 'coerce')
# C:\Users\DELL E6400\AppData\Local\Temp\ipykernel_14752\4117476002.py:4: SettingWithCopyWarning:
# ...

# %%
#Breakdown order time into year, month and hour
df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
df['Year'] = df['Order Date'].dt.year
df['Month'] = df['Order Date'].dt.month
df['Day'] = df['Order Date'].dt.day
df['Hour'] = df['Order Date'].dt.hour
df.head()
# Out:
# C:\Users\DELL E6400\AppData\Local\Temp\ipykernel_14752\2192045806.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Order Date'] = pd.to_datetime(df['Order Date'], errors='coerce')
# C:\Users\DELL E6400\AppData\Local\Temp\ipykernel_14752\2192045806.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Year'] = df['Order Date'].dt.year
# C:\Users\DELL E6400\AppData\Local\Temp\ipykernel_14752\2192045806.py:4: SettingWithCopyWarning:
# ...

# %%
#total annual sales per month
months={1.0:'Jan', 2.0:'Feb', 3.0:'Mar', 4.0:'Apr',5.0:'May',6.0:'Jun',7.0:'Jul',8.0:'Aug', 9.0:'Sept',10.0:'0ct',11.0:'Nov', 12.0:'Dec'}
df2 = df.replace({'Month': months})
#print (df2.head())
total_annual_sales = df2.groupby(['Month']).Amount_Sold.sum().sort_values(ascending=True)
print(total_annual_sales)
total_annual_sales.plot(kind='bar', color=(0.2, 0.4, 0.6, 0.6),figsize=(16, 8))
plt.title('Total annual sales per month')
plt.ylabel('Total annual sales')

plt.show()
# Out:
# Month
# Jan     1822256.73
# Sept    2097560.13
# Feb     2202022.42
# Aug     2244467.88
# Jun     2577802.26
# Jul     2647775.76
# Mar     2807100.38
# May     3152606.75
# Nov     3199603.20
# Apr     3390670.24
# 0ct     3736726.88
# Dec     4613443.34
# Name: Amount_Sold, dtype: float64

# %%
#correlation matrix
plt.figure(figsize=(24, 8))
sns.heatmap(df.corr(), annot=True);

# %%
df.corr()['Amount_Sold'].sort_values(ascending=False)
# Out:
# Amount_Sold         1.000000
# Price Each          0.999203
# Year                0.002824
# Hour                0.001668
# Day                -0.002580
# Month              -0.003466
# Quantity Ordered   -0.139417
# Name: Amount_Sold, dtype: float64

# %%
plt.figure(figsize=(24, 6))
sns.barplot(
    x=df['Month'], 
    y=df['Amount_Sold'], 
    data=total_annual_sales, palette='deep'
)
# title
plt.title('Month Sales and Much Earned in that Months', 
          fontname='monospace', weight='bold'
)
# x-label
plt.xlabel('Months')
# y-label
plt.ylabel('Sales in USD ($)');

# %%
#States with highest number of sales
states= df.groupby(['State']).Amount_Sold.sum()
states.plot(kind='bar', color=(0.2, 0.4, 0.6, 0.6),figsize=(16, 8))
plt.title('States with highest number of sales')
plt.ylabel('Total annual sales')
plt.show()

# %%
#Hours with the largest quantity of orders
orders= df.groupby(['Hour'])['Quantity Ordered'].sum()
orders.plot(color=(0.2, 0.4, 0.6, 0.6),figsize=(16, 4))
plt.style.use('seaborn-whitegrid')
plt.title('Hours with highest number of orders')
plt.ylabel('Total number of orders')
plt.show()

# %%
product= df.groupby(['Product'])['Quantity Ordered'].sum().sort_values(ascending=False)
print (product)
product.plot(kind='bar',color=(0.2, 0.4, 0.6, 0.6),figsize=(16, 4))
plt.style.use('default')
plt.title('Products with highest number of orders')
plt.ylabel('Total number of orders')
plt.show()
# Out:
# Product
# AAA Batteries (4-pack)        31017.0
# AA Batteries (4-pack)         27635.0
# USB-C Charging Cable          23975.0
# Lightning Charging Cable      23217.0
# Wired Headphones              20557.0
# Apple Airpods Headphones      15661.0
# Bose SoundSport Headphones    13457.0
# 27in FHD Monitor               7550.0
# iPhone                         6849.0
# 27in 4K Gaming Monitor         6244.0
# 34in Ultrawide Monitor         6199.0
# Google Phone                   5532.0
# Flatscreen TV                  4819.0
# Macbook Pro Laptop             4728.0
# ThinkPad Laptop                4130.0
# 20in Monitor                   4129.0
# Vareebadd Phone                2068.0
# LG Washing Machine              666.0
# LG Dryer                        646.0
# Product                           0.0
# Name: Quantity Ordered, dtype: float64
